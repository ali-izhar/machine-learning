# %% [markdown]
# ## Import Libraries

# %%
# !pip install openai --quiet
# !pip install tenacity --quiet

# %%
import json

import pandas as pd
import numpy as np


import openai
from tenacity import retry, wait_random_exponential, stop_after_attempt

# %% [markdown]
# ### Load Data

# %%
## Load data
path = 'data/Coursera.csv'
data = pd.read_csv(path)

# %%
data.head()
# Out:
#                                          course_name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                   university difficulty_level course_rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           course_url  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# 4  https://www.coursera.org/learn/single-table-sq...
#
#                                          description  \
# 0  Write a Full Length Feature Film Script  In th...
# 1  By the end of this guided project, you will be...
# 2  This course consists of a general presentation...
# 3  When it comes to numbers, there is always more...
# 4  In this course you�ll learn how to effectively...
#
#                                               skills
# 0  Drama  Comedy  peering  screenwriting  film  D...
# 1  Finance  business plan  persona (user experien...
# 2  chemistry  physics  Solar Energy  film  lambda...
# 3  accounts receivable  dupont analysis  analysis...
# 4  Data Analysis  select (sql)  database manageme...

# %%
data.columns
# Out:
# Index(['course_name', 'university', 'difficulty_level', 'course_rating',
#        'course_url', 'description', 'skills'],
#       dtype='object')

# %%
## check for missing values
print(data.isnull().sum())
# Out:
# course_name         0
# university          0
# difficulty_level    0
# course_rating       0
# course_url          0
# description         0
# skills              0
# dtype: int64

# %% [markdown]
# ### Create embeddings for the courses name

# %%
def get_embeddings(text):
    response = openai.Embedding.create(
        input = text,
        model = "text-embedding-ada-002",
    )["data"][0]["embedding"]
    return response

# %%
## read api key
key = json.load(open('api.json'))

# %%
# Set up your OpenAI API credentials
openai.api_key = key['open_api']

## get embeddings for all courses
data['embedding'] = data['course_name'].apply(get_embeddings)

# %%
data.head()
# Out:
#                                          course_name  \
# 0  Write A Feature Length Screenplay For Film Or ...
# 1  Business Strategy: Business Model Canvas Analy...
# 2                      Silicon Thin Film Solar Cells
# 3                               Finance for Managers
# 4       Retrieve Data using Single-Table SQL Queries
#
#                   university difficulty_level course_rating  \
# 0  Michigan State University         Beginner           4.8
# 1   Coursera Project Network         Beginner           4.8
# 2        �cole Polytechnique         Advanced           4.1
# 3       IESE Business School     Intermediate           4.8
# 4   Coursera Project Network         Beginner           4.6
#
#                                           course_url  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
# 3  https://www.coursera.org/learn/operational-fin...
# 4  https://www.coursera.org/learn/single-table-sq...
#
#                                          description  \
# 0  Write a Full Length Feature Film Script  In th...
# 1  By the end of this guided project, you will be...
# 2  This course consists of a general presentation...
# 3  When it comes to numbers, there is always more...
# 4  In this course you�ll learn how to effectively...
#
#                                               skills  \
# 0  Drama  Comedy  peering  screenwriting  film  D...
# 1  Finance  business plan  persona (user experien...
# 2  chemistry  physics  Solar Energy  film  lambda...
# 3  accounts receivable  dupont analysis  analysis...
# 4  Data Analysis  select (sql)  database manageme...
#
#                                            embedding
# 0  [0.004957424942404032, -0.013018687255680561, ...
# 1  [-0.011336499825119972, -0.022729190066456795,...
# 2  [0.002505358075723052, -0.006338656414300203, ...
# 3  [-0.0029222306329756975, -0.03425585851073265,...
# 4  [-0.016929104924201965, 0.013173501938581467, ...

# %%
## save the csv file with embeddings
data.to_csv('data/Coursera_embeddings.csv', index=False)

# %%
## function to get the similarity score between embeddings
def get_similarity_score(embedding1, embedding2):
    return np.inner(embedding1, embedding2)

# %%
## get the recommendations for a given course
def get_recommendation(user_prompt, data, similarity_score_threshold=0.5, top_n=5):
    user_embedding = get_embeddings(user_prompt)
    data['similarity_score'] = data['embedding'].apply(lambda x: get_similarity_score(user_embedding, x))
    data = data[data['similarity_score'] >= similarity_score_threshold]
    data = data.sort_values(by='similarity_score', ascending=False)
    return data.head(top_n)

# %%
## get the recommendations for a given course
course = 'World History and Religion'
get_recommendation(course, data)
# Out:
#                                             course_name  \
# 3405  Philosophy, Science and Religion: Religion and...
# 2681                             Science & Religion 101
# 28    Philosophy, Science and Religion: Philosophy a...
# 1313  Philosophy, Science and Religion: Science and ...
# 2870                          Roman Art and Archaeology
#
#                        university difficulty_level course_rating  \
# 3405  The University of Edinburgh         Beginner           4.4
# 2681        University of Alberta   Not Calibrated           4.5
# 28    The University of Edinburgh     Intermediate           4.6
# 1313  The University of Edinburgh         Beginner           4.3
# 2870        University of Arizona         Beginner           4.7
#
#                                              course_url  \
# 3405  https://www.coursera.org/learn/philosophy-scie...
# 2681  https://www.coursera.org/learn/science-and-rel...
# 28    https://www.coursera.org/learn/philosophy-scie...
# 1313  https://www.coursera.org/learn/philosophy-scie...
# 2870  https://www.coursera.org/learn/roman-art-archa...
#
#                                             description  \
# 3405  Philosophy, Science and Religion mark three of...
# 2681  This course examines the nature of both scienc...
# 28    Philosophy, Science and Religion mark three of...
# 1313  Philosophy, Science and Religion mark three of...
# 2870  The objective of this course is to provide an ...
#
#                                                  skills  \
# 3405  reason  evolution  belief  mythology  religion...
# 2681  astronomy  dichotomy  hermeneutics  evolutiona...
# 28    ordered pair  arts and humanities  virtue  spi...
# 1313  evolution  sociology  history  evolutionary bi...
# 2870  greek mythology  Archeology  history  scientif...
#
#                                               embedding  similarity_score
# 3405  [0.016331691294908524, -0.0006601900095120072,...          0.877774
# 2681  [0.024437962099909782, -0.002743568504229188, ...          0.877461
# 28    [0.011801879853010178, -0.0004650808987207711,...          0.872059
# 1313  [0.015422379598021507, -0.001257329131476581, ...          0.865002
# 2870  [0.006569115910679102, -0.0016763578169047832,...          0.860288
