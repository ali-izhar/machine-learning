# %% [markdown]
# # State-Action value function
# Imagine a Mars rover navigating through a set terrain. At any given moment, it's in one of 6 possible states. From each state, the rover has two potential actions: move left or move right. The journey has two terminal states, each associated with a distinct reward. By adjusting the discount factor, we can determine the optimal policy the rover should follow.

# %%
import numpy as np
from utils import *

# %%
num_states = 6
num_actions = 2

# %%
terminal_left_reward = 100
terminal_right_reward = 40
each_step_reward = 0

# Discount factor
gamma = 0.5

# Probability of going in the wrong direction
misstep_prob = 0

# %%
generate_visualization(terminal_left_reward, terminal_right_reward, each_step_reward, gamma, misstep_prob)

# %%
# focus on future rewards (less impatient); move towards higher rewards terminal end
gamma = 0.9

# %%
generate_visualization(terminal_left_reward, terminal_right_reward, each_step_reward, gamma, misstep_prob)
